# %%
from matplotlib import pyplot as plt
import pylab
import numpy as np

# %%
xs = [0,1, 2, 4, 8, 16, 32]
ys_1loop = [0,(22500), (45500), (48500), (48800), (49000), (49900)]
ys_1hloop = [0,(20500), (40500), (44500), (45000), (45500), (45800)]
ys_1tloop = [0,(50000/8), (22000/1), (25000/1), (27000/1), (27400/1), (27600/1)]
ys_10tloop = [0,(30000/16), (80000/27), (39000/12), (30000/8), (30200/7), (33300/7)]
ys_100tloop = [0,(30000/147), (30000/75), (30000/51), (30000/50), (30000/49), (30000/44)]
ys_500tloop = [0,(5000/114), (5000/62), (5000/41), (5000/40), (5000/38), (5000/37)]

# %%
# plt.plot(xs,ys_1loop)
# plt.plot(xs,ys_1hloop)
plt.plot(xs,ys_1hloop)
plt.plot(xs,ys_1tloop)

# %%
xs
# Out:
# [0, 1, 2, 4, 8, 16, 32]

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)
ax.plot(xs,ys_1loop,label='NUM_LOOPS=1')
ax.plot(xs,ys_1hloop,label='NUM_LOOPS=100')
ax.plot(xs,ys_1tloop,label='NUM_LOOPS=1000')
ax.plot(xs,ys_10tloop,label='NUM_LOOPS=10000')
ax.plot(xs,ys_100tloop,label='NUM_LOOPS=100000')
ax.plot(xs,ys_500tloop,label='NUM_LOOPS=500000')
ax.set_yscale('log')
ax.legend()

ax.grid()
pylab.show()
