# %%
from matplotlib import pyplot as plt
import pylab
import numpy as np

# %%
xs = [0,1, 2, 4, 8, 16, 32]
ys_1loop = [0,(10869.565217), (17565.548775), (18565.511235), (22522.522523), (17158.544955), (14467.592593)]
ys_1hloop = [0,(10084.711577), (18377.750104), (18007.846844), (27685.492802), (21795.989538), (14188.422247)]
ys_1tloop = [0,(5878.151309), (8253.549026), (13842.746401), (11682.242991), (16479.894529), (12124.151309)]
ys_10tloop = [0,(1995.689311), (3584.674897), (4529.806124), (6475.006475), (3812.719231), (4889.546753)]
ys_100tloop = [0,(195.765207), (480.736447), (588.235294), (601.580154), (612.244895), (681.818181)]
ys_500tloop = [0,(43.859649), (80.645161), (121.951252), (125.548687), (131.578947), (135.135135)]

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)
ax.plot(xs,ys_1loop,label='NUM_LOOPS=1')
ax.plot(xs,ys_1hloop,label='NUM_LOOPS=100')
ax.plot(xs,ys_1tloop,label='NUM_LOOPS=1000')
ax.plot(xs,ys_10tloop,label='NUM_LOOPS=10000')
ax.plot(xs,ys_100tloop,label='NUM_LOOPS=100000')
ax.plot(xs,ys_500tloop,label='NUM_LOOPS=500000')
ax.set_yscale('log')
ax.legend()
ax.title.set_text('Running 64 clients in parallel on port 4324')
ax.grid()
pylab.show()
fig.savefig('graph.png')
